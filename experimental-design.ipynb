# %% [markdown]
# # YOLOv11s VisDrone Training — Kaggle Version
# Make sure you have added the following datasets via (**+ Add Input**):
# 1. VisDrone dataset (with train/val images)
#
# Set **Accelerator → GPU T4 x2** in Session options.
# Set Persistence to variables and files in Session options.
# Set Internet on in Session Options.

# %%
# !pip install ultralytics tqdm pillow -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 20.5 MB/s eta 0:00:00a 0:00:01

# %%
import os

VISDRONE_INPUT = "/kaggle/input/datasets/dabiraomotoso/visdrone/VisDrone"          # folder of VisDrone dataset

OUTPUT_DIR = "/kaggle/working/runs/baseline_yolo11s"
os.makedirs(OUTPUT_DIR, exist_ok=True)

# Print input contents to verify folder names
print("=== /kaggle/input contents ===")
for d in os.listdir("/kaggle/input"):
    print(" ", d)
# Out:
# === /kaggle/input contents ===
#   datasets

# %%
# Verifying expected folders exist
TRAIN_IMAGES  = os.path.join(VISDRONE_INPUT, "VisDrone2019-DET-train/images")
VAL_IMAGES    = os.path.join(VISDRONE_INPUT, "VisDrone2019-DET-val/images")
TEST_IMAGES   = os.path.join(VISDRONE_INPUT, "VisDrone2019-DET-test-challenge/images")
TRAIN_LABELS  = os.path.join(VISDRONE_INPUT, "VisDrone2019-DET-train/labels")
VAL_LABELS    = os.path.join(VISDRONE_INPUT, "VisDrone2019-DET-val/labels")

for path in [TRAIN_IMAGES, VAL_IMAGES, TEST_IMAGES, TRAIN_LABELS, VAL_LABELS]:
    status = "OK" if os.path.exists(path) else "NOT FOUND"
    print(f"[{status}] {path}")
# Out:
# [OK] /kaggle/input/datasets/dabiraomotoso/visdrone/VisDrone/VisDrone2019-DET-train/images
# [OK] /kaggle/input/datasets/dabiraomotoso/visdrone/VisDrone/VisDrone2019-DET-val/images
# [OK] /kaggle/input/datasets/dabiraomotoso/visdrone/VisDrone/VisDrone2019-DET-test-challenge/images
# [OK] /kaggle/input/datasets/dabiraomotoso/visdrone/VisDrone/VisDrone2019-DET-train/labels
# [OK] /kaggle/input/datasets/dabiraomotoso/visdrone/VisDrone/VisDrone2019-DET-val/labels

# %%
# ── Labels already converted in preprocessing notebook ───────────────────
print("Skipping conversion — labels already exist in dataset.")
print(f"  Train labels: {len(os.listdir(TRAIN_LABELS))} files")
print(f"  Val labels:   {len(os.listdir(VAL_LABELS))} files")
# Out:
# Skipping conversion — labels already exist in dataset.
#   Train labels: 6471 files
#   Val labels:   548 files

# %%
# Write data.yaml with my paths 
import yaml

data = {
    "path": VISDRONE_INPUT,
    "train": "VisDrone2019-DET-train/images",
    "val":   "VisDrone2019-DET-val/images",
    "test":  "VisDrone2019-DET-test-challenge/images",
    "nc": 10,
    "names": {
        0: "pedestrian",
        1: "people",
        2: "bicycle",
        3: "car",
        4: "van",
        5: "truck",
        6: "tricycle",
        7: "awning-tricycle",
        8: "bus",
        9: "motor"
    }
}

YAML_PATH = "/kaggle/working/data.yaml"
with open(YAML_PATH, "w") as f:
    yaml.dump(data, f, default_flow_style=False, sort_keys=False)

print("data.yaml written to:", YAML_PATH)
# !cat /kaggle/working/data.yaml
# Out:
# data.yaml written to: /kaggle/working/data.yaml
# path: /kaggle/input/datasets/dabiraomotoso/visdrone/VisDrone
# train: VisDrone2019-DET-train/images
# val: VisDrone2019-DET-val/images
# test: VisDrone2019-DET-test-challenge/images
# nc: 10
# names:
#   0: pedestrian
#   1: people
#   2: bicycle
#   3: car
#   4: van
#   5: truck
#   6: tricycle
#   7: awning-tricycle
#   8: bus
#   9: motor

# %%
from ultralytics import YOLO

model = YOLO("yolo11s.pt")

results = model.train(
    data    = YAML_PATH,
    epochs  = 1,
    imgsz   = 640,
    batch   = 16,
    project = "/kaggle/working/runs",
    name    = "baseline_yolo11s",
    exist_ok= True,
)
print("Sanity check passed!")
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo11s.pt to 'yolo11s.pt': 100% ━━━━━━━━━━━━ 18.4MB 50.5MB/s 0.4s0.3s<0.1ss
# Ultralytics 8.4.26 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/kaggle/working/data.yaml, degrees=0.0, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=1, erasing=0.4, exist_ok=True, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo11s.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=baseline_yolo11s, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=/kaggle/working/runs, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/kaggle/working/runs/baseline_yolo11s, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf': 100% ━━━━━━━━━━━━ 755.1KB 5.0MB/s 0.1s 0.1s<0.2s
# Overriding model.yaml nc=80 with nc=10
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   3                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   4                  -1  1    103360  ultralytics.nn.modules.block.C3k2            [128, 256, 1, False, 0.25]
#   5                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#   6                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1380352  ultralytics.nn.modules.block.C3k2            [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1    990976  ultralytics.nn.modules.block.C2PSA           [512, 512, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    443776  ultralytics.nn.modules.block.C3k2            [768, 256, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1    127680  ultralytics.nn.modules.block.C3k2            [512, 128, 1, False]
#  17                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1    345472  ultralytics.nn.modules.block.C3k2            [384, 256, 1, False]
#  20                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1   1511424  ultralytics.nn.modules.block.C3k2            [768, 512, 1, True]
#  23        [16, 19, 22]  1    823278  ultralytics.nn.modules.head.Detect           [10, 16, None, [128, 256, 512]]
# YOLO11s summary: 182 layers, 9,431,662 parameters, 9,431,646 gradients, 21.6 GFLOPs
#
# Transferred 493/499 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo26n.pt to 'yolo26n.pt': 100% ━━━━━━━━━━━━ 5.3MB 21.1MB/s 0.3s.2s<0.1s0s
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.2±0.3 ms, read: 37.9±33.0 MB/s, size: 260.7 KB)
# train: Scanning /kaggle/input/datasets/dabiraomotoso/visdrone/VisDrone/VisDrone2019-DET-train/labels... 6471 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 6471/6471 247.2it/s 26.2s0.1ss
# train: /kaggle/input/datasets/dabiraomotoso/visdrone/VisDrone/VisDrone2019-DET-train/images/0000137_02220_d_0000163.jpg: 1 duplicate labels removed
# train: /kaggle/input/datasets/dabiraomotoso/visdrone/VisDrone/VisDrone2019-DET-train/images/0000140_00118_d_0000002.jpg: 1 duplicate labels removed
# train: /kaggle/input/datasets/dabiraomotoso/visdrone/VisDrone/VisDrone2019-DET-train/images/9999945_00000_d_0000114.jpg: 1 duplicate labels removed
# train: /kaggle/input/datasets/dabiraomotoso/visdrone/VisDrone/VisDrone2019-DET-train/images/9999987_00000_d_0000049.jpg: 1 duplicate labels removed
# WARNING ⚠️ train: Cache directory /kaggle/input/datasets/dabiraomotoso/visdrone/VisDrone/VisDrone2019-DET-train is not writable, cache not saved.
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 32.4±8.6 MB/s, size: 142.1 KB)
# val: Scanning /kaggle/input/datasets/dabiraomotoso/visdrone/VisDrone/VisDrone2019-DET-val/labels... 548 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 548/548 63.9it/s 8.6s0.1ss
# WARNING ⚠️ val: Cache directory /kaggle/input/datasets/dabiraomotoso/visdrone/VisDrone/VisDrone2019-DET-val is not writable, cache not saved.
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.000714, momentum=0.9) with parameter groups 81 weight(decay=0.0), 88 weight(decay=0.0005), 87 bias(decay=0.0)
# Plotting labels to /kaggle/working/runs/baseline_yolo11s/labels.jpg...
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to /kaggle/working/runs/baseline_yolo11s
# Starting training for 1 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         1/1      10.1G      1.644      1.609     0.9686        628        640: 100% ━━━━━━━━━━━━ 405/405 2.7it/s 2:32<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 1.2it/s 15.6s0.4s
#                    all        548      38759       0.33      0.256      0.231      0.129
#
# 1 epochs completed in 0.048 hours.
# Optimizer stripped from /kaggle/working/runs/baseline_yolo11s/weights/last.pt, 19.2MB
# Optimizer stripped from /kaggle/working/runs/baseline_yolo11s/weights/best.pt, 19.2MB
#
# Validating /kaggle/working/runs/baseline_yolo11s/weights/best.pt...
# Ultralytics 8.4.26 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# YOLO11s summary (fused): 101 layers, 9,416,670 parameters, 0 gradients, 21.3 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 2.1it/s 8.4s0.3s
#                    all        548      38759       0.33      0.256      0.231      0.129
#             pedestrian        520       8844       0.31      0.379      0.311       0.13
#                 people        482       5125      0.443      0.153      0.192     0.0624
#                bicycle        364       1287      0.223     0.0412     0.0468     0.0162
#                    car        515      14064      0.454      0.732      0.672      0.446
#                    van        421       1975      0.317      0.311       0.25      0.166
#                  truck        266        750      0.305      0.207      0.182      0.113
#               tricycle        337       1045      0.326     0.0842      0.116     0.0681
#        awning-tricycle        220        532      0.267     0.0132      0.051     0.0327
#                    bus        131        251       0.31      0.319      0.237      0.163
#                  motor        485       4886      0.349      0.322      0.253     0.0906
# Speed: 0.1ms preprocess, 2.6ms inference, 0.0ms loss, 2.3ms postprocess per image
# Results saved to /kaggle/working/runs/baseline_yolo11s
# Sanity check passed!

# %%
from ultralytics import YOLO

model = YOLO("yolo11s.pt")

results = model.train(
    data     = YAML_PATH,
    epochs   = 200,
    imgsz    = 640,
    batch    = 16,
    patience = 50,
    project  = "/kaggle/working/runs",
    name     = "baseline_yolo11s",
    exist_ok = True,
)
# Out:
# Ultralytics 8.4.26 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/kaggle/working/data.yaml, degrees=0.0, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=200, erasing=0.4, exist_ok=True, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo11s.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=baseline_yolo11s, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=50, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=/kaggle/working/runs, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/kaggle/working/runs/baseline_yolo11s, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Overriding model.yaml nc=80 with nc=10
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   3                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   4                  -1  1    103360  ultralytics.nn.modules.block.C3k2            [128, 256, 1, False, 0.25]
#   5                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#   6                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1380352  ultralytics.nn.modules.block.C3k2            [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1    990976  ultralytics.nn.modules.block.C2PSA           [512, 512, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    443776  ultralytics.nn.modules.block.C3k2            [768, 256, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1    127680  ultralytics.nn.modules.block.C3k2            [512, 128, 1, False]
#  17                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1    345472  ultralytics.nn.modules.block.C3k2            [384, 256, 1, False]
#  20                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1   1511424  ultralytics.nn.modules.block.C3k2            [768, 512, 1, True]
#  23        [16, 19, 22]  1    823278  ultralytics.nn.modules.head.Detect           [10, 16, None, [128, 256, 512]]
# YOLO11s summary: 182 layers, 9,431,662 parameters, 9,431,646 gradients, 21.6 GFLOPs
#
# Transferred 493/499 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 449.3±207.1 MB/s, size: 261.9 KB)
# train: Scanning /kaggle/input/datasets/dabiraomotoso/visdrone/VisDrone/VisDrone2019-DET-train/labels... 6471 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 6471/6471 902.3it/s 7.2s0.1s
# train: /kaggle/input/datasets/dabiraomotoso/visdrone/VisDrone/VisDrone2019-DET-train/images/0000137_02220_d_0000163.jpg: 1 duplicate labels removed
# train: /kaggle/input/datasets/dabiraomotoso/visdrone/VisDrone/VisDrone2019-DET-train/images/0000140_00118_d_0000002.jpg: 1 duplicate labels removed
# train: /kaggle/input/datasets/dabiraomotoso/visdrone/VisDrone/VisDrone2019-DET-train/images/9999945_00000_d_0000114.jpg: 1 duplicate labels removed
# train: /kaggle/input/datasets/dabiraomotoso/visdrone/VisDrone/VisDrone2019-DET-train/images/9999987_00000_d_0000049.jpg: 1 duplicate labels removed
# WARNING ⚠️ train: Cache directory /kaggle/input/datasets/dabiraomotoso/visdrone/VisDrone/VisDrone2019-DET-train is not writable, cache not saved.
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 179.3±42.4 MB/s, size: 131.6 KB)
# val: Scanning /kaggle/input/datasets/dabiraomotoso/visdrone/VisDrone/VisDrone2019-DET-val/labels... 548 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 548/548 700.1it/s 0.8s0.1s
# WARNING ⚠️ val: Cache directory /kaggle/input/datasets/dabiraomotoso/visdrone/VisDrone/VisDrone2019-DET-val is not writable, cache not saved.
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: MuSGD(lr=0.01, momentum=0.9) with parameter groups 81 weight(decay=0.0), 88 weight(decay=0.0005), 87 bias(decay=0.0)
# Plotting labels to /kaggle/working/runs/baseline_yolo11s/labels.jpg...
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to /kaggle/working/runs/baseline_yolo11s
# Starting training for 200 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/200      10.2G      1.637      1.544     0.9749        628        640: 100% ━━━━━━━━━━━━ 405/405 2.2it/s 3:02<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 3.6it/s 5.0s0.3s
#                    all        548      38759      0.347      0.269      0.248      0.137
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       2/200       8.6G      1.638       1.26     0.9407        478        640: 100% ━━━━━━━━━━━━ 405/405 2.6it/s 2:37<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 3.4it/s 5.2s0.3s
#                    all        548      38759      0.378      0.287      0.268      0.147
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       3/200      8.81G      1.715      1.304     0.9539        642        640: 100% ━━━━━━━━━━━━ 405/405 2.7it/s 2:28<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 3.4it/s 5.3s0.3s
#                    all        548      38759      0.332      0.251      0.237      0.132
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       4/200      8.46G      1.701       1.29     0.9561        657        640: 100% ━━━━━━━━━━━━ 405/405 2.8it/s 2:25<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 3.5it/s 5.1s0.3s
#                    all        548      38759      0.367      0.274      0.259      0.143
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       5/200       6.9G      1.652      1.239     0.9459        835        640: 100% ━━━━━━━━━━━━ 405/405 2.8it/s 2:25<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 3.6it/s 5.0s0.3s
#                    all        548      38759      0.371      0.304      0.278      0.156
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       6/200       8.9G      1.631      1.203     0.9372        315        640: 100% ━━━━━━━━━━━━ 405/405 2.8it/s 2:25<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 3.6it/s 5.0s0.3s
#                    all        548      38759      0.393      0.298      0.291      0.162
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       7/200      9.61G      1.592      1.167     0.9309        581        640: 100% ━━━━━━━━━━━━ 405/405 2.8it/s 2:25<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 3.7it/s 4.9s0.3s
#                    all        548      38759      0.413      0.313      0.305      0.171
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       8/200      11.1G      1.577      1.137     0.9239        487        640: 100% ━━━━━━━━━━━━ 405/405 2.8it/s 2:26<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 3.6it/s 4.9s0.3s
#                    all        548      38759      0.416      0.321      0.315       0.18
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       9/200      8.51G      1.545       1.11     0.9201        643        640: 100% ━━━━━━━━━━━━ 405/405 2.8it/s 2:26<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 3.6it/s 5.0s0.3s
#                    all        548      38759      0.421      0.334      0.324      0.185
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      10/200      8.65G      1.545      1.107     0.9173        644        640: 100% ━━━━━━━━━━━━ 405/405 2.8it/s 2:25<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 3.6it/s 5.0s0.3s
#                    all        548      38759      0.398      0.329      0.313       0.18
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      11/200      9.51G      1.526      1.086     0.9136        634        640: 100% ━━━━━━━━━━━━ 405/405 2.8it/s 2:25<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 3.7it/s 4.9s0.3s
#                    all        548      38759      0.426      0.328      0.326      0.188
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      12/200      9.43G      1.523      1.072     0.9084        847        640: 100% ━━━━━━━━━━━━ 405/405 2.8it/s 2:26<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 3.6it/s 5.0s0.3s
#                    all        548      38759      0.436      0.344      0.337      0.194
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      13/200      10.3G      1.506      1.062     0.9096        273        640: 100% ━━━━━━━━━━━━ 405/405 2.8it/s 2:25<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 3.7it/s 4.9s0.3s
#                    all        548      38759      0.429      0.349      0.339      0.195
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      14/200      9.32G      1.486      1.044     0.9058        611        640: 100% ━━━━━━━━━━━━ 405/405 2.8it/s 2:25<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 3.6it/s 4.9s0.3s
#                    all        548      38759      0.441      0.345      0.338      0.193
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      15/200      8.38G      1.486      1.033     0.9014        527        640: 100% ━━━━━━━━━━━━ 405/405 2.8it/s 2:25<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 3.6it/s 5.0s0.3s
#                    all        548      38759      0.459      0.357      0.354      0.203
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      16/200      9.75G      1.478      1.026     0.9001        880        640: 100% ━━━━━━━━━━━━ 405/405 2.8it/s 2:26<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 3.7it/s 4.9s0.3s
#                    all        548      38759       0.44      0.346      0.343        0.2
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      17/200      9.16G      1.478      1.022      0.899        554        640: 100% ━━━━━━━━━━━━ 405/405 2.8it/s 2:26<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 3.7it/s 4.9s0.3s
#                    all        548      38759      0.456       0.35      0.355      0.206
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      18/200      9.14G      1.471      1.018     0.9006        398        640: 100% ━━━━━━━━━━━━ 405/405 2.8it/s 2:26<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 3.7it/s 4.9s0.3s
#                    all        548      38759      0.452      0.357      0.356      0.208
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      19/200      8.09G      1.456      1.006     0.8953        309        640: 100% ━━━━━━━━━━━━ 405/405 2.8it/s 2:25<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 3.7it/s 4.9s0.3s
#                    all        548      38759      0.448      0.355      0.357      0.207
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      20/200      8.97G      1.454     0.9944     0.8961        829        640: 100% ━━━━━━━━━━━━ 405/405 2.8it/s 2:25<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 3.7it/s 4.8s0.3s
#                    all        548      38759      0.477      0.361      0.366      0.213
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      21/200      8.37G      1.451     0.9915     0.8959        490        640: 100% ━━━━━━━━━━━━ 405/405 2.8it/s 2:25<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 3.7it/s 4.8s0.3s
#                    all        548      38759      0
640: 100% ━━━━━━━━━━━━ 405/405 2.8it/s 2:26<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 3.8it/s 4.8s0.3s
#                    all        548      38759       0.53      0.399      0.414      0.246
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     134/200      7.19G      1.226     0.7124     0.8444        624        640: 100% ━━━━━━━━━━━━ 405/405 2.8it/s 2:25<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 3.8it/s 4.8s0.3s
#                    all        548      38759      0.527        0.4      0.413      0.246
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     135/200      7.19G      1.219     0.7096     0.8468        918        640: 100% ━━━━━━━━━━━━ 405/405 2.8it/s 2:24<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 3.8it/s 4.7s0.3s
#                    all        548      38759      0.527      0.401      0.414      0.246
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     136/200      7.19G      1.222     0.7108     0.8467        639        640: 100% ━━━━━━━━━━━━ 405/405 2.8it/s 2:26<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 3.8it/s 4.8s0.3s
#                    all        548      38759      0.529        0.4      0.414      0.246
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     137/200      7.19G      1.212     0.7043     0.8458        475        640: 100% ━━━━━━━━━━━━ 405/405 2.8it/s 2:25<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 3.8it/s 4.8s0.3s
#                    all        548      38759      0.525        0.4      0.414      0.246
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     138/200      7.19G      1.215     0.7064     0.8469        452        640: 100% ━━━━━━━━━━━━ 405/405 2.8it/s 2:25<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 3.8it/s 4.8s0.3s
#                    all        548      38759      0.523      0.402      0.414      0.246
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     139/200      7.19G      1.212      0.703     0.8455        544        640: 100% ━━━━━━━━━━━━ 405/405 2.8it/s 2:26<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 3.8it/s 4.7s0.3s
#                    all        548      38759      0.527      0.398      0.414      0.246
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     140/200      9.62G      1.217     0.7029     0.8453        535        640: 100% ━━━━━━━━━━━━ 405/405 2.8it/s 2:26<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 3.8it/s 4.8s0.3s
#                    all        548      38759      0.529      0.398      0.414      0.246
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     141/200      10.2G      1.211     0.7017     0.8453        556        640: 100% ━━━━━━━━━━━━ 405/405 2.8it/s 2:25<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 3.8it/s 4.8s0.3s
#                    all        548      38759      0.531        0.4      0.414      0.246
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     142/200      7.45G      1.205     0.6985     0.8458        432        640: 100% ━━━━━━━━━━━━ 405/405 2.8it/s 2:25<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 3.8it/s 4.8s0.3s
#                    all        548      38759      0.535      0.397      0.414      0.246
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     143/200      7.68G      1.211     0.6985     0.8449        727        640: 100% ━━━━━━━━━━━━ 405/405 2.8it/s 2:25<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 3.8it/s 4.7s0.3s
#                    all        548      38759      0.535      0.399      0.415      0.246
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     144/200      7.34G      1.207     0.6938     0.8457        529        640: 100% ━━━━━━━━━━━━ 405/405 2.8it/s 2:26<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 3.7it/s 4.8s0.3s
#                    all        548      38759      0.533        0.4      0.414      0.246
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     145/200      6.77G      1.205     0.6945     0.8439        705        640: 100% ━━━━━━━━━━━━ 405/405 2.8it/s 2:26<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 3.8it/s 4.8s0.3s
#                    all        548      38759      0.526      0.403      0.414      0.246
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     146/200      7.79G      1.208     0.6967     0.8434        439        640: 100% ━━━━━━━━━━━━ 405/405 2.8it/s 2:25<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 3.7it/s 4.9s0.3s
#                    all        548      38759      0.529      0.402      0.413      0.246
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     147/200      9.83G      1.199     0.6894     0.8442        375        640: 100% ━━━━━━━━━━━━ 405/405 2.8it/s 2:25<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 3.8it/s 4.8s0.3s
#                    all        548      38759      0.529      0.401      0.414      0.246
# EarlyStopping: Training stopped early as no improvement observed in last 50 epochs. Best results observed at epoch 97, best model saved as best.pt.
# To update EarlyStopping(patience=50) pass a new patience value, i.e. `patience=300` or use `patience=0` to disable EarlyStopping.
#
# 147 epochs completed in 6.178 hours.
# Optimizer stripped from /kaggle/working/runs/baseline_yolo11s/weights/last.pt, 19.2MB
# Optimizer stripped from /kaggle/working/runs/baseline_yolo11s/weights/best.pt, 19.2MB
#
# Validating /kaggle/working/runs/baseline_yolo11s/weights/best.pt...
# Ultralytics 8.4.26 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# YOLO11s summary (fused): 101 layers, 9,416,670 parameters, 0 gradients, 21.3 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 2.1it/s 8.5s0.3s
#                    all        548      38759      0.536      0.405      0.418      0.249
#             pedestrian        520       8844      0.554      0.434      0.467      0.212
#                 people        482       5125      0.554      0.309       0.35      0.133
#                bicycle        364       1287      0.297      0.169      0.149     0.0635
#                    car        515      14064      0.704      0.806      0.811      0.575
#                    van        421       1975      0.582      0.421      0.449      0.318
#                  truck        266        750      0.576      0.372      0.394      0.264
#               tricycle        337       1045      0.472      0.342      0.317      0.173
#        awning-tricycle        220        532      0.338      0.164      0.163     0.0986
#                    bus        131        251      0.767      0.534      0.597       0.44
#                  motor        485       4886      0.517      0.498      0.483      0.217
# Speed: 0.1ms preprocess, 2.6ms inference, 0.0ms loss, 1.7ms postprocess per image
# Results saved to /kaggle/working/runs/baseline_yolo11s

# %%
# Plot training curves
import pandas as pd
import matplotlib.pyplot as plt

csv_path = "/kaggle/working/runs/baseline_yolo11s/results.csv"
df = pd.read_csv(csv_path)
df.columns = df.columns.str.strip()

fig, axes = plt.subplots(1, 2, figsize=(14, 5))

axes[0].plot(df["epoch"], df["train/box_loss"], label="Train Box Loss")
axes[0].plot(df["epoch"], df["val/box_loss"],   label="Val Box Loss")
axes[0].set_title("Box Loss: Train vs Validation")
axes[0].set_xlabel("Epoch")
axes[0].set_ylabel("Loss")
axes[0].legend()
axes[0].grid(True)

axes[1].plot(df["epoch"], df["metrics/mAP50(B)"],    label="mAP@50")
axes[1].plot(df["epoch"], df["metrics/mAP50-95(B)"], label="mAP@50-95")
axes[1].set_title("mAP over Training")
axes[1].set_xlabel("Epoch")
axes[1].set_ylabel("mAP")
axes[1].legend()
axes[1].grid(True)

plt.tight_layout()
plt.savefig("/kaggle/working/loss_curves.png", dpi=150)
plt.show()
print("Plot saved.")
# Out:
# Plot saved.

# %%
import zipfile
import os

zip_path = "/kaggle/working/baseline_yolo11s_export.zip"

to_include = [
    "/kaggle/working/runs",
    "/kaggle/working/loss_curves.png",
    "/kaggle/working/data.yaml"
]

with zipfile.ZipFile(zip_path, 'w', zipfile.ZIP_DEFLATED) as zf:
    for path in to_include:
        if os.path.isdir(path):
            for root, dirs, files in os.walk(path):
                for file in files:
                    full_path = os.path.join(root, file)
                    arcname = os.path.relpath(full_path, "/kaggle/working")
                    zf.write(full_path, arcname)
        elif os.path.isfile(path):
            arcname = os.path.relpath(path, "/kaggle/working")
            zf.write(path, arcname)
        else:
            print(f"Not found: {path}")

print(f"Saved to: {zip_path}")
# Out:
# Saved to: /kaggle/working/baseline_yolo11s_export.zip
